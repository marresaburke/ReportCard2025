# %%
import pandas as pd

test_1 = pd.DataFrame({"Score": ['A','B'], "Subject":['Math','Reading']},index=["2024", "2024"])


test_2 = pd.DataFrame({"Score": ['C','A'], "Subject":['Math','Reading']},index=["2025", "2025"])


test_1
# Out:
#      Score  Subject
# 2024     A     Math
# 2024     B  Reading

# %%
import pandas as pd 
old_scores = pd.read_csv('/Users/marresaburke/Desktop/Report-Card2025/ReportCard2025/KY2024report.csv', index_col = 0)
District = old_scores.groupby(by ='District Name').get_group('Jefferson County')
District
# Out:
#              County Number County Name  District Number     District Name  \
# School Year
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# ...                    ...         ...              ...               ...
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
# 20232024              56.0   JEFFERSON              275  Jefferson County
#
#              School Number             School Name  School Code  \
# School Year
# 20232024               4.0  Camp Taylor Elementary       275004
# 20232024               4.0  Camp Taylor Elementary       275004
# 20232024               4.0  Camp Taylor Elementary       275004
# 20232024               4.0  Camp Taylor Elementary       275004
# 20232024               4.0  Camp Taylor Elementary       275004
# ...                    ...                     ...          ...
# 20232024               NaN             All Schools       275000
# 20232024               NaN             All Schools       275000
# 20232024               NaN             All Schools       275000
# 20232024               NaN             All Schools       275000
# 20232024               NaN             All Schools       275000
#
#              State School Id       NCES ID Co-Op  ...  School Type    Grade  \
# School Year                                       ...
# 20232024          56275004.0  2.102990e+11  GLEC  ...           A1  Grade 3
# 20232024          56275004.0  2.102990e+11  GLEC  ...           A1  Grade 3
# 20232024          56275004.0  2.102990e+11  GLEC  ...           A1  Grade 3
# 20232024          56275004.0  2.102990e+11  GLEC  ...           A1  Grade 3
# 20232024          56275004.0  2.102990e+11  GLEC  ...           A1  Grade 3
# ...                      ...           ...   ...  ...          ...      ...
# 20232024                 NaN           NaN  GLEC  ...          NaN  Grade 8
# 20232024                 NaN           NaN  GLEC  ...          NaN  Grade 8
# 20232024                 NaN           NaN  GLEC  ...          NaN  Grade 8
# 20232024                 NaN           NaN  GLEC  ...          NaN  Grade 8
# 20232024                 NaN           NaN  GLEC  ...          NaN  Grade 8
#
#                     Subject  \
# School Year
# 20232024        Mathematics
# 20232024        Mathematics
# 20232024        Mathematics
# 20232024        Mathematics
# 20232024        Mathematics
# ...                     ...
# 20232024     Social Studies
# 20232024     Social Studies
# 20232024     Social Studies
# 20232024     Social Studies
# 20232024     Social Studies
#
#                                                    Demographic Suppressed  \
# School Year
# 20232024                                      African American          Y
# 20232024                                          All Students          N
# 20232024                                  Alternate Assessment          Y
# 20232024                      American Indian or Alaska Native        NaN
# 20232024                                                 Asian          Y
# ...                                                        ...        ...
# 20232024                      Students with Disabilities (IEP)          N
# 20232024     Students with Disabilities/IEP Regular Assessment          N
# 20232024     Students with Disabilities/IEP with Accommodat...          N
# 20232024                                     Two or More Races          N
# 20232024                                  White (non-Hispanic)          N
#
#             Novice Apprentice Proficient Distinguished  \
# School Year
# 20232024         *          *          *             *
# 20232024        41         30         25             3
# 20232024         *          *          *             *
# 20232024       NaN        NaN        NaN           NaN
# 20232024         *          *          *             *
# ...            ...        ...        ...           ...
# 20232024        77         18          3             1
# 20232024        84         12          3             1
# 20232024        84         11          4             1
# 20232024        45         25         19            12
# 20232024        40         23         24            14
#
#             Proficient / Distinguished
# School Year
# 20232024                             *
# 20232024                            29
# 20232024                             *
# 20232024                           NaN
# 20232024                             *
# ...                                ...
# 20232024                             5
# 20232024                             4
# 20232024                             5
# 20232024                            31
# 20232024                            38
#
# [52235 rows x 21 columns]
